# %%
import re
import collections

# %%
def parse_fasta(file):
    results = {}
    f = open(file,"r")
    contents = f.read()
    f.close()
    strings = contents.strip().split('>')
    for s in strings:
        if len(s) == 0:
            continue
        parts = s.split()
        label = parts[0]
        bases = ''.join(parts[1:])
        results[label] = bases
    return results

# %%
parse_fasta("E:\\Biddle Lab\\Rosalind Project\\datasets\\rosalind_gc.txt")
# Out:
# {'Rosalind_4316': '...',
#  'Rosalind_8190': '...',
#  'Rosalind_7506': '...',
#  'Rosalind_3661': '...',
#  'Rosalind_1504': '...',
#  'Rosalind_6498': '...',
#  'Rosalind_3701': '...',
#  'Rosalind_6012': '...',
#  'Rosalind_2557': '...',
#  'Rosalind_9665': '...'}

# %%
def MaxGCcontent(file):
    finalresults = {}
    finalresults = parse_fasta(file)
    for key in finalresults:
        sequence = finalresults[key]
        totallen = len(sequence)
        gccontent = 0
        print(key)
        print(sequence)
        for i in sequence:
            if i == "C" or i == "G":
                gccontent += 1
        gcratio = (gccontent/totallen) * 100
        finalresults[key] = gcratio
        print(gcratio)
    #for key in finalresults:
        #print(key)
        #print(finalresults[key])
    the_max = max(finalresults, key = lambda key: finalresults[key])
    print(the_max)
    print(finalresults[the_max])

# %%
MaxGCcontent("E:\\Biddle Lab\\Rosalind Project\\rosalind_gc.txt")
# Out:
# Rosalind_4316
# ...
# 47.82608695652174
# Rosalind_8190
# ...
# 44.183445190156604
# Rosalind_7506
# ...
# 48.14027630180659
# Rosalind_3661
# ...
# 49.88864142538976
# Rosalind_1504
# ...
# 47.69736842105263
# Rosalind_6498
# ...
# 50.475184794086594
# Rosalind_3701
# ...
# 49.94663820704376
# Rosalind_6012
# ...
# 48.59307359307359
# Rosalind_2557
# ...
# 49.877149877149876
# Rosalind_9665
# ...
# 52.595936794582386
# Rosalind_9665
# 52.595936794582386
